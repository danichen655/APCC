# %%
import numpy as np

from pyquil import Program
from pyquil.gates import RX, RZ, MEASURE

qubit = 0

p = Program()
ro = p.declare("ro", "BIT", 1)
theta_ref = p.declare("theta", "REAL")

p += RX(np.pi / 2, qubit)
p += RZ(theta_ref, qubit)
p += RX(-np.pi / 2, qubit)

p += MEASURE(qubit, ro[0])

# %%
from pyquil import get_qc

# Get a Quantum Virtual Machine to simulate execution
qc = get_qc("1q-qvm")
executable = qc.compile(p)
# Out:
# WARNING - Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f3ba346d250>: Failed to establish a new connection: [Errno 111] Connection refused')': /
# WARNING - Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f3ba346d490>: Failed to establish a new connection: [Errno 111] Connection refused')': /
# WARNING - Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f3ba346d700>: Failed to establish a new connection: [Errno 111] Connection refused')': /
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# ~/.local/lib/python3.8/site-packages/urllib3/connection.py in _new_conn(self)
#     168         try:
# --> 169             conn = connection.create_connection(
#     170                 (self._dns_host, self.port), self.timeout, **extra_kw
#
# ~/.local/lib/python3.8/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      95     if err is not None:
# ---> 96         raise err
#      97
#
# ~/.local/lib/python3.8/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      85                 sock.bind(source_address)
# ---> 86             sock.connect(sa)
#      87             return sock
#
# ConnectionRefusedError: [Errno 111] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# ~/.local/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#
# ~/.local/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     393             else:
# --> 394                 conn.request(method, url, **httplib_request_kw)
#     395
#
# ~/.local/lib/python3.8/site-packages/urllib3/connection.py in request(self, method, url, body, headers)
#     233             headers["User-Agent"] = _get_default_user_agent()
# --> 234         super(HTTPConnection, self).request(method, url, body=body, headers=headers)
#     235
#
# ~/anaconda3/envs/forestEnv/lib/python3.8/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1254         """Send a complete request to the server."""
# -> 1255         self._send_request(method, url, body, headers, encode_chunked)
#    1256
#
# ~/anaconda3/envs/forestEnv/lib/python3.8/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1300             body = _encode(body, 'body')
# -> 1301         self.endheaders(body, encode_chunked=encode_chunked)
#    1302
#
# ~/anaconda3/envs/forestEnv/lib/python3.8/http/client.py in endheaders(self, message_body, encode_chunked)
#    1249             raise CannotSendHeader()
# -> 1250         self._send_output(message_body, encode_chunked=encode_chunked)
#    1251
#
# ~/anaconda3/envs/forestEnv/lib/python3.8/http/client.py in _send_output(self, message_body, encode_chunked)
#    1009         del self._buffer[:]
# -> 1010         self.send(msg)
#    1011
#
# ~/anaconda3/envs/forestEnv/lib/python3.8/http/client.py in send(self, data)
#     949             if self.auto_open:
# --> 950                 self.connect()
#     951             else:
#
# ~/.local/lib/python3.8/site-packages/urllib3/connection.py in connect(self)
#     199     def connect(self):
# --> 200         conn = self._new_conn()
#     201         self._prepare_conn(conn)
#
# ~/.local/lib/python3.8/site-packages/urllib3/connection.py in _new_conn(self)
#     180         except SocketError as e:
# --> 181             raise NewConnectionError(
#     182                 self, "Failed to establish a new connection: %s" % e
#
# NewConnectionError: <urllib3.connection.HTTPConnection object at 0x7f3ba346d940>: Failed to establish a new connection: [Errno 111] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# ~/.local/lib/python3.8/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#
# ~/.local/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     782             )
# --> 783             return self.urlopen(
#     784                 method,
#
# ~/.local/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     782             )
# --> 783             return self.urlopen(
#     784                 method,
#
# ~/.local/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     782             )
# --> 783             return self.urlopen(
#     784                 method,
#
# ~/.local/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     754
# --> 755             retries = retries.increment(
#     756                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#
# ~/.local/lib/python3.8/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     572         if new_retry.is_exhausted():
# --> 573             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     574
#
# MaxRetryError: HTTPConnectionPool(host='127.0.0.1', port=5000): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f3ba346d940>: Failed to establish a new connection: [Errno 111] Connection refused'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# ~/anaconda3/envs/forestEnv/lib/python3.8/site-packages/pyquil/api/_qvm.py in connect(self)
#     491         try:
# --> 492             version_dict = self.get_version_info()
#     493             check_qvm_version(version_dict)
#
# ~/anaconda3/envs/forestEnv/lib/python3.8/site-packages/pyquil/api/_error_reporting.py in wrapper(*args, **kwargs)
#     250
# --> 251         val = func(*args, **kwargs)
#     252
#
# ~/anaconda3/envs/forestEnv/lib/python3.8/site-packages/pyquil/api/_qvm.py in get_version_info(self)
#     503         """
# --> 504         return cast(str, self.connection._qvm_get_version_info())
#     505
#
# ~/anaconda3/envs/forestEnv/lib/python3.8/site-packages/pyquil/api/_error_reporting.py in wrapper(*args, **kwargs)
#     250
# --> 251         val = func(*args, **kwargs)
#     252
#
# ~/anaconda3/envs/forestEnv/lib/python3.8/site-packages/pyquil/api/_base_connection.py in _qvm_get_version_info(self)
#     627         """
# --> 628         response = post_json(self.session, self.sync_endpoint, {"type": "version"})
#     629         split_version_string = response.text.split()
#
# ~/anaconda3/envs/forestEnv/lib/python3.8/site-packages/pyquil/api/_base_connection.py in post_json(session, url, json)
#      62     logger.debug("Sending POST request to %s. Body: %s", url, json)
# ---> 63     res = session.post(url, json=json)
#      64     if res.status_code >= 400:
#
# ~/.local/lib/python3.8/site-packages/requests/sessions.py in post(self, url, data, json, **kwargs)
#     589
# --> 590         return self.request('POST', url, data=data, json=json, **kwargs)
#     591
#
# ~/anaconda3/envs/forestEnv/lib/python3.8/site-packages/pyquil/api/_base_connection.py in request(self, *args, **kwargs)
#     471         """
# --> 472         response = super().request(*args, **kwargs)
#     473         if response.status_code in {401, 403}:
#
# ~/.local/lib/python3.8/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#
# ~/.local/lib/python3.8/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#
# ~/.local/lib/python3.8/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     515
# --> 516             raise ConnectionError(e, request=request)
#     517
#
# ConnectionError: HTTPConnectionPool(host='127.0.0.1', port=5000): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f3ba346d940>: Failed to establish a new connection: [Errno 111] Connection refused'))
#
# During handling of the above exception, another exception occurred:
#
# QVMNotRunning                             Traceback (most recent call last)
# <ipython-input-5-5fccdf27b592> in <module>
#       2
#       3 # Get a Quantum Virtual Machine to simulate execution
# ----> 4 qc = get_qc("1q-qvm")
#       5 executable = qc.compile(p)
#
# ~/anaconda3/envs/forestEnv/lib/python3.8/site-packages/pyquil/api/_error_reporting.py in wrapper(*args, **kwargs)
#     249             global_error_context.log[key] = pre_entry
#     250
# --> 251         val = func(*args, **kwargs)
#     252
#     253         # poke the return value of that call in
#
# ~/anaconda3/envs/forestEnv/lib/python3.8/site-packages/pyquil/api/_quantum_computer.py in get_qc(***failed resolving arguments***)
#     907         if qvm_type is None:
#     908             raise ValueError("Please name a valid device or run as a QVM")
# --> 909         return _get_unrestricted_qvm(
#     910             name=name,
#     911             connection=connection,
#
# ~/anaconda3/envs/forestEnv/lib/python3.8/site-packages/pyquil/api/_quantum_computer.py in _get_unrestricted_qvm(name, noisy, n_qubits, connection, qvm_type, compiler_timeout)
#     769     """
#     770     topology = nx.complete_graph(n_qubits)
# --> 771     return _get_qvm_with_topology(
#     772         name=name,
#     773         connection=connection,
#
# ~/anaconda3/envs/forestEnv/lib/python3.8/site-packages/pyquil/api/_quantum_computer.py in _get_qvm_with_topology(name, topology, noisy, requires_executable, connection, qvm_type, compiler_timeout)
#     706     else:
#     707         noise_model = None
# --> 708     return _get_qvm_qc(
#     709         name=name,
#     710         qvm_type=qvm_type,
#
# ~/anaconda3/envs/forestEnv/lib/python3.8/site-packages/pyquil/api/_quantum_computer.py in _get_qvm_qc(name, qvm_type, device, noise_model, requires_executable, connection, compiler_timeout)
#     659     return QuantumComputer(
#     660         name=name,
# --> 661         qam=_get_qvm_or_pyqvm(
#     662             qvm_type=qvm_type,
#     663             connection=connection,
#
# ~/anaconda3/envs/forestEnv/lib/python3.8/site-packages/pyquil/api/_quantum_computer.py in _get_qvm_or_pyqvm(qvm_type, connection, noise_model, device, requires_executable)
#     620 ) -> Union[QVM, PyQVM]:
#     621     if qvm_type == "qvm":
# --> 622         return QVM(
#     623             connection=connection, noise_model=noise_model, requires_executable=requires_executable
#     624         )
#
# ~/anaconda3/envs/forestEnv/lib/python3.8/site-packages/pyquil/api/_error_reporting.py in wrapper(*args, **kwargs)
#     249             global_error_context.log[key] = pre_entry
#     250
# --> 251         val = func(*args, **kwargs)
#     252
#     253         # poke the return value of that call in
#
# ~/anaconda3/envs/forestEnv/lib/python3.8/site-packages/pyquil/api/_qvm.py in __init__(self, connection, noise_model, gate_noise, measurement_noise, random_seed, requires_executable)
#     486
#     487         self.requires_executable = requires_executable
# --> 488         self.connect()
#     489
#     490     def connect(self) -> None:
#
# ~/anaconda3/envs/forestEnv/lib/python3.8/site-packages/pyquil/api/_qvm.py in connect(self)
#     493             check_qvm_version(version_dict)
#     494         except ConnectionError:
# --> 495             raise QVMNotRunning(f"No QVM server running at {self.connection.sync_endpoint}")
#     496
#     497     @_record_call
#
# QVMNotRunning: No QVM server running at http://127.0.0.1:5000
